# %%
import pandas as pd
nba = pd.read_csv("nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["Name"] #data exist
nba["Sport"] #error generate, data/columns not exist
# Out:
# 0      Basketball
# 1      Basketball
# 2      Basketball
# 3      Basketball
# 4      Basketball
# 5      Basketball
# 6      Basketball
# 7      Basketball
# 8      Basketball
# 9      Basketball
# 10     Basketball
# 11     Basketball
# 12     Basketball
# 13     Basketball
# 14     Basketball
# 15     Basketball
# 16     Basketball
# 17     Basketball
# 18     Basketball
# 19     Basketball
# 20     Basketball
# 21     Basketball
# 22     Basketball
# 23     Basketball
# 24     Basketball
# 25     Basketball
# 26     Basketball
# 27     Basketball
# 28     Basketball
# 29     Basketball
#           ...
# 428    Basketball
# 429    Basketball
# 430    Basketball
# 431    Basketball
# 432    Basketball
# 433    Basketball
# 434    Basketball
# 435    Basketball
# 436    Basketball
# 437    Basketball
# 438    Basketball
# 439    Basketball
# 440    Basketball
# 441    Basketball
# 442    Basketball
# 443    Basketball
# 444    Basketball
# 445    Basketball
# 446    Basketball
# ...

# %%
nba["Sport"] = "Basketball"
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba["Leage"] = "National Basket Ball Asoo"
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport                      Leage
# 0              Texas  7730337.0  Basketball  National Basket Ball Asoo
# 1          Marquette  6796117.0  Basketball  National Basket Ball Asoo
# 2  Boston University        NaN  Basketball  National Basket Ball Asoo
# 3      Georgia State  1148640.0  Basketball  National Basket Ball Asoo
# 4                NaN  5000000.0  Basketball  National Basket Ball Asoo

# %%
#in between columns insert the new columns 
nba1 = pd.read_csv("nba.csv")
nba1.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba1.insert(3,column="Sport",value="Basket Ball")
nba1.head()
# Out:
#             Name            Team  Number        Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basket Ball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basket Ball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basket Ball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basket Ball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basket Ball       PF  29.0   6-10
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %%
nba1.insert(4,column="League",value="PSL")
nba1.head()
# Out:
#             Name            Team  Number        Sport League Position   Age  \
# 0  Avery Bradley  Boston Celtics     0.0  Basket Ball    PSL       PG  25.0
# 1    Jae Crowder  Boston Celtics    99.0  Basket Ball    PSL       SF  25.0
# 2   John Holland  Boston Celtics    30.0  Basket Ball    PSL       SG  27.0
# 3    R.J. Hunter  Boston Celtics    28.0  Basket Ball    PSL       SG  22.0
# 4  Jonas Jerebko  Boston Celtics     8.0  Basket Ball    PSL       PF  29.0
#
#   Height  Weight            College     Salary
# 0    6-2   180.0              Texas  7730337.0
# 1    6-6   235.0          Marquette  6796117.0
# 2    6-5   205.0  Boston University        NaN
# 3    6-5   185.0      Georgia State  1148640.0
# 4   6-10   231.0                NaN  5000000.0
